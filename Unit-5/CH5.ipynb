# %%
#CH5
# JE SHODHAVU HOY E Y
# JENA PAR DEPEND HOY E X
#6.89,3.26

# %%
import pandas as pd
data = pd.read_csv("Book1.csv")
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
data.shape #imp
# Out:
# (200, 2)

# %%
data.info() #imp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
data.describe()  #imp
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
data.isna().sum()  #imp
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
#upar nu badhu badha model ma karavu

# %%
y = data['package']
#y = data.iloc[:,1]
#y = data.iloc[:,-1]
x = data.iloc[:,0:1]
print(type(y)) # y e series hovi joie
print(type(x)) # x e DataFrame hovu joie
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# x_train
# x_test
# y_train
# y_test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160,)
# (40,)

# %%
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.2,random_state=1)
# print(x_train)
# #,random_state=1 apava thi e ek no ek data apse
# Out:
#      cgpa
# 190  6.19
# 30   7.36
# 121  6.50
# 115  8.35
# 175  7.04
# 8    6.09
# 60   5.61
# 128  7.93
# 1    5.12
# 57   6.60
# 22   6.14
# 61   5.48
# 63   9.16
# 7    6.75
# 196  5.89
# 141  6.76
# 86   7.61
# 96   7.11
# 68   7.56
# 50   9.58
# 142  6.93
# 157  6.47
# 156  7.38
# 139  7.19
# 146  6.07
# 101  6.71
# 20   7.28
# 178  8.15
# 25   7.28
# 134  7.20
# 71   7.47
# 129  7.29
# 144  6.17
# 192  8.25
# 79   7.18
# 133  6.05
# 137  7.14
# 72   7.78
# 140  7.91
# 37   5.90

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)
print(ypred)
# Out:
# [3.89111601 3.09324469 2.38464568 2.57434935 1.6537286  1.77647803
#  2.07219258 2.93143862 3.76278706 2.93701814 4.09197872 3.51170867
#  2.97049525 2.40138424 3.18809652 3.46707251 1.94386362 3.24389172
#  2.97607477 3.41685683 2.55761079 3.16577844 2.85890486 3.12114229
#  3.68467378 2.8700639  3.49497011 3.34432308 3.91901361 1.96060218
#  3.65119666 3.2104146  3.74046898 2.7863711  2.78079158 3.27178932
#  3.52844723 2.61340599 2.65804215 2.71383735]

# %%
diff = pd.DataFrame({"Actual":y_test,"Predicted":ypred})
diff
# Out:
#      Actual  Predicted
# 58     3.09   2.912140
# 40     4.02   4.328025
# 34     3.42   3.153876
# 102    1.37   1.881882
# 184    3.14   3.464680
# ..      ...        ...
# 3      3.67   3.199921
# 169    4.37   4.287735
# 49     4.62   4.034488
# 149    3.67   3.694906
# 131    2.01   2.595580
#
# [160 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(data['cgpa'],data['package'])
plt.plot(x_test,ypred,color='red')
plt.show()

# %%
#ypred=lr.predict([[9.5]])
#print(ypred)
#[4.40443183]

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)
# Out:
# coefficients :  [0.57556302]
# Intercept :  -1.070756254084971

# %%
from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y_test,ypred))
print("MSE : ",metrics.mean_squared_error(y_test,ypred))
# Out:
# MAE :  0.2708176687319257
# MSE :  0.11085592034539729

# %%
####################################################################################################################################

# %%
import pandas as pd
data = pd.read_csv("Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
y = data['Sales']


x = data.iloc[:,1:4]
print(y)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(x)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)
print(ypred)
# Out:
# [14.0533655   9.3596964   6.84168105 15.57542062 18.24566528 15.69705683
#   7.30213681 20.55741282 12.91982687 17.56977582 10.56954425 19.44183679
#   9.02152837 10.39883137 14.23578821 12.14385282  8.89722911 17.65602288
#  16.59817803 18.63325138 16.91499972 16.20074839 11.56907383 11.79479752
#  15.14324825 12.31833158 15.39070301  7.93709454 16.78291467 14.14997697
#  16.66592168 16.81179836 13.06481745 12.90749021  8.53383456 10.87895886
#  21.98983006 20.14333152 16.31534821 19.97848869]

# %%
diff = pd.DataFrame({"Actual":y_test,"Predicted":ypred})
diff
# Out:
#      Actual  Predicted
# 112    14.1  14.053366
# 29     10.5   9.359696
# 182     8.7   6.841681
# 199    13.4  15.575421
# 193    19.6  18.245665
# 85     15.2  15.697057
# 10      8.6   7.302137
# 54     20.2  20.557413
# 115    12.6  12.919827
# 35     12.8  17.569776
# 12      9.2  10.569544
# 92     19.4  19.441837
# 13      9.7   9.021528
# 126     6.6  10.398831
# 174    11.5  14.235788
# 2       9.3  12.143853
# 44      8.5   8.897229
# 3      18.5  17.656023
# 113    15.9  16.598178
# 14     19.0  18.633251
# 23     15.5  16.915000
# 25     12.0  16.200748
# 6      11.8  11.569074
# 134    10.8  11.794798
# 165    11.9  15.143248
# 173    11.7  12.318332
# 45     14.9  15.390703
# 65      9.3   7.937095
# 48     14.8  16.782915
# 122    11.6  14.149977
# 178    11.8  16.665922
# 64     18.0  16.811798
# 9      10.6  13.064817
# 57     13.2  12.907490
# 78      5.3   8.533835
# 71     12.4  10.878959
# 128    24.7  21.989830
# 176    20.2  20.143332
# 131    12.7  16.315348
# ...

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)

from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y_test,ypred))
print("MSE : ",metrics.mean_squared_error(y_test,ypred))
# Out:
# coefficients :  [0.04735257 0.17323832 0.00466519]
# Intercept :  3.0544520115813825
# MAE :  1.6462745449078693
# MSE :  4.503125945046122

# %%
import matplotlib.pyplot as plt
plt.scatter(data['TV'],data['Radio'],data['Newspaper'],data['Sales'])
plt.plot(x_test,ypred,color='red')
plt.show()

# %%
##############################################################################################################################

import pandas as pd
data = pd.read_csv("insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
data = pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92         0           1                 0
# 1   18  33.8         1   1725.55         1           0                 0
# 2   28  33.0         3   4449.46         1           0                 0
# 3   33  22.7         0  21984.47         1           0                 1
# 4   32  28.9         0   3866.86         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
x=data[['age','bmi','smoker_yes']]
y=data['expenses']

# %%
print(x)
# Out:
#       age   bmi  smoker_yes
# 0      19  27.9           1
# 1      18  33.8           0
# 2      28  33.0           0
# 3      33  22.7           0
# 4      32  28.9           0
# ...   ...   ...         ...
# 1333   50  31.0           0
# 1334   18  31.9           0
# 1335   18  36.9           0
# 1336   21  25.8           0
# 1337   61  29.1           1
#
# [1338 rows x 3 columns]

# %%
print(y)
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
 from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1070, 3)
# (268, 3)
# (1070,)
# (268,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)
print(ypred)
# Out:
# [ 4637.51377691 13263.37670795 13378.82350781 12739.55362115
#   1149.5765212  31133.83181494 13012.67762322 12124.36975842
#   3826.06396472 30259.70723156 11915.90107603 17099.31546983
#   8845.22062699  8620.58811469  4044.75483151 10538.39777468
#   4378.25361436  6413.49062271 15298.6137163  15073.981204
#  12514.92110884 32301.20532732  9261.83854985  9963.7832077
#   2739.82904385  8179.56472599  8393.97505388 11479.15822625
#   7473.65897114  4451.15056996 14309.36177497  5942.12012267
#  33249.568531   27267.86538362 32956.319602   10042.62180881
#  31148.01509636 25904.22592178 15828.69789052 33575.46456174
#   6209.30247923 14402.38365749 10327.94854379 15480.69638435
#   4133.49617513 13160.13264101  4835.76027488 29537.63764679
#   7643.21946437 12444.00470175 14329.48670189 12199.24726252
#   2351.25824192  8395.95560238 25643.30465263 10643.94183202
#  33694.8724586  15132.69487818  2244.05307798  6654.60640684
# ...

# %%
diff = pd.DataFrame({"Actual":y_test,"Predicted":ypred})
diff
# Out:
#         Actual     Predicted
# 559    1646.43   4637.513777
# 1087  11353.23  13263.376708
# 1020   8798.59  13378.823508
# 460   10381.48  12739.553621
# 802    2103.08   1149.576521
# ...        ...           ...
# 682   40103.89  33478.481582
# 629   42983.46  35896.028305
# 893   44202.65  36642.503356
# 807    2136.88   4971.332002
# 1165   5227.99   5927.936841
#
# [268 rows x 2 columns]

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)

from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y_test,ypred))
print("MSE : ",metrics.mean_squared_error(y_test,ypred))
# Out:
# coefficients :  [  258.94072065   303.47111341 23722.84761499]
# Intercept :  -11055.584441475958
# MAE :  4107.492142539742
# MSE :  36305111.1936047

# %%
#################################################################################]{}
########################################NDA########################################]{}
############################{NARENDRA DAMODARDAS MODI}#############################]{}
#################################################################################]{}

# %%
import pandas as pd
data = pd.read_csv("car data.csv")

data.drop('Car_Name',axis=1,inplace=True)
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
data['Age']=2024-data['Year']
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   10
# ...

# %%
data.drop('Year',axis=1,inplace=True)
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# 3         Manual      0   13
# ...

# %%
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   10                 0
# 1             4.75           9.54       43000      0   11                 1
# 2             7.25           9.85        6900      0    7                 0
# 3             2.85           4.15        5200      0   13                 0
# 4             4.60           6.87       42450      0   10                 1
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    8                 1
# 297           4.00           5.90       60000      0    9                 0
# 298           3.35          11.00       87934      0   15                 0
# 299          11.50          12.50        9000      0    7                 1
# 300           5.30           5.90        5464      0    8                 0
#
# ...

# %%
data.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'Age',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
x=data.iloc[:,1:9]
y=data['Selling_Price']

print(x)

print(y)
# Out:
#      Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             5.59       27000      0   10                 0
# 1             9.54       43000      0   11                 1
# 2             9.85        6900      0    7                 0
# 3             4.15        5200      0   13                 0
# 4             6.87       42450      0   10                 1
# ..             ...         ...    ...  ...               ...
# 296          11.60       33988      0    8                 1
# 297           5.90       60000      0    9                 0
# 298          11.00       87934      0   15                 0
# 299          12.50        9000      0    7                 1
# 300           5.90        5464      0    8                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# 1                   0                       0                    1
# ...

# %%
 from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
print("x shape",x.shape)
print("y shape",y.shape)
# Out:
# (240, 8)
# (61, 8)
# (240,)
# (61,)
# x shape (301, 8)
# y shape (301,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)
print(ypred)
# Out:
# [ 7.86273200e+00  2.96828691e+00 -5.90305107e-01  4.21335952e+00
#   4.83175534e-01  5.82053813e+00  1.95679784e+00  2.55809661e+00
#   7.70870833e+00  9.78692192e-01  8.13484343e+00  3.51207180e+00
#   4.90669281e+00  4.63905587e+00 -2.15886643e+00  3.13874624e+00
#   7.98256903e+00  6.75937638e+00  6.90426580e+00  8.01440587e+00
#   4.31168610e+00  4.00336757e+00  1.13040883e+01  8.07939189e+00
#   9.54399823e+00  3.52133877e+00  3.80609808e+00  1.06074722e+00
#  -6.01732475e-01 -6.19712043e-01  1.32818516e-03 -1.28500691e+00
#   4.28533553e+00  2.06769487e+01  1.87563232e+01  4.27292100e+00
#   3.48602852e+00  1.66739677e+00 -4.38707073e-02  5.78536030e+00
#   8.03940428e+00  9.88367483e+00  4.09684249e-01  6.07997517e+00
#   5.88038915e+00  4.32745252e+00  7.37534505e+00  5.86171335e+00
#   8.21129880e+00  1.65455816e+00  3.83033706e+00  1.75047060e+00
#   2.51406796e+00  4.20404709e+00  1.48991546e+00 -3.44185843e+00
# ...

# %%
diff = pd.DataFrame({"Actual":y_test,"Predicted":ypred})
diff
# Out:
#      Actual  Predicted
# 285    7.40   7.862732
# 248    4.00   2.968287
# 150    0.50  -0.590305
# 217    3.15   4.213360
# 107    1.25   0.483176
# ..      ...        ...
# 62    18.75  20.480622
# 154    0.50   0.662504
# 218    6.45   5.400274
# 286    5.65   5.658562
# 186    0.25   0.647876
#
# [61 rows x 2 columns]

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)

from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y_test,ypred))
print("MSE : ",metrics.mean_squared_error(y_test,ypred))
print("R2 SCORE : ",metrics.r2_score(y_test,ypred))
# Out:
# coefficients :  [ 4.37233976e-01 -5.30613944e-06  3.45912849e-01 -4.13270098e-01
#   2.23050770e+00  4.58549217e-01 -1.20927814e+00 -1.87014327e+00]
# Intercept :  7.073759933489655
# MAE :  1.099857555299095
# MSE :  2.9823848618597486
# R2 SCORE :  0.8625260513315253

# %%
x.columns
# Out:
# Index(['Present_Price', 'Kms_Driven', 'Owner', 'Age', 'Fuel_Type_Diesel',
#        'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual'],
#       dtype='object')

# %%
ypred=lr.predict([[5.5,30000,0,10,0,1,1,1]])
ypred
# Out:
# array([2.56578944])

# %%
import pandas as pd
data = pd.read_csv("FuelConsumptionCo2.csv")
data
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
data.drop('MAKE',axis=1,inplace=True)
data
# Out:
#       MODELYEAR       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014         ILX         COMPACT         2.0          4
# 1          2014         ILX         COMPACT         2.4          4
# 2          2014  ILX HYBRID         COMPACT         1.5          4
# 3          2014     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014     RDX AWD     SUV - SMALL         3.5          6
# ...         ...         ...             ...         ...        ...
# 1062       2014    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# ...

# %%
data['Age']=2024-data['MODELYEAR']
data
# Out:
#       MODELYEAR       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014         ILX         COMPACT         2.0          4
# 1          2014         ILX         COMPACT         2.4          4
# 2          2014  ILX HYBRID         COMPACT         1.5          4
# 3          2014     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014     RDX AWD     SUV - SMALL         3.5          6
# ...         ...         ...             ...         ...        ...
# 1062       2014    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# ...

# %%
data.drop('MODELYEAR',axis=1,inplace=True)
data
# Out:
#            MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0            ILX         COMPACT         2.0          4          AS5        Z
# 1            ILX         COMPACT         2.4          4           M6        Z
# 2     ILX HYBRID         COMPACT         1.5          4          AV7        Z
# 3        MDX 4WD     SUV - SMALL         3.5          6          AS6        Z
# 4        RDX AWD     SUV - SMALL         3.5          6          AS6        Z
# ...          ...             ...         ...        ...          ...      ...
# 1062    XC60 AWD     SUV - SMALL         3.0          6          AS6        X
# 1063    XC60 AWD     SUV - SMALL         3.2          6          AS6        X
# 1064    XC70 AWD     SUV - SMALL         3.0          6          AS6        X
# 1065    XC70 AWD     SUV - SMALL         3.2          6          AS6        X
# 1066    XC90 AWD  SUV - STANDARD         3.2          6          AS6        X
#
# ...

# %%
data.drop('VEHICLECLASS',axis=1,inplace=True)
data
# Out:
#            MODEL  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0            ILX         2.0          4          AS5        Z
# 1            ILX         2.4          4           M6        Z
# 2     ILX HYBRID         1.5          4          AV7        Z
# 3        MDX 4WD         3.5          6          AS6        Z
# 4        RDX AWD         3.5          6          AS6        Z
# ...          ...         ...        ...          ...      ...
# 1062    XC60 AWD         3.0          6          AS6        X
# 1063    XC60 AWD         3.2          6          AS6        X
# 1064    XC70 AWD         3.0          6          AS6        X
# 1065    XC70 AWD         3.2          6          AS6        X
# 1066    XC90 AWD         3.2          6          AS6        X
#
#       FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                      9.9                  6.7                   8.5
# 1                     11.2                  7.7                   9.6
# ...

# %%
data.drop('TRANSMISSION',axis=1,inplace=True)
data
# Out:
#            MODEL  ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            ILX         2.0          4        Z                   9.9
# 1            ILX         2.4          4        Z                  11.2
# 2     ILX HYBRID         1.5          4        Z                   6.0
# 3        MDX 4WD         3.5          6        Z                  12.7
# 4        RDX AWD         3.5          6        Z                  12.1
# ...          ...         ...        ...      ...                   ...
# 1062    XC60 AWD         3.0          6        X                  13.4
# 1063    XC60 AWD         3.2          6        X                  13.2
# 1064    XC70 AWD         3.0          6        X                  13.4
# 1065    XC70 AWD         3.2          6        X                  12.9
# 1066    XC90 AWD         3.2          6        X                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# ...

# %%
data.drop('MODEL',axis=1,inplace=True)
data
# Out:
#       ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            2.0          4        Z                   9.9
# 1            2.4          4        Z                  11.2
# 2            1.5          4        Z                   6.0
# 3            3.5          6        Z                  12.7
# 4            3.5          6        Z                  12.1
# ...          ...        ...      ...                   ...
# 1062         3.0          6        X                  13.4
# 1063         3.2          6        X                  13.2
# 1064         3.0          6        X                  13.4
# 1065         3.2          6        X                  12.9
# 1066         3.2          6        X                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                     6.7                   8.5                        33
# 1                     7.7                   9.6                        29
# ...

# %%
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS  Age  \
# ...

# %%
data.corr()
# Out:
#                           ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE                  1.000000   0.934011              0.832225
# CYLINDERS                   0.934011   1.000000              0.796473
# FUELCONSUMPTION_CITY        0.832225   0.796473              1.000000
# FUELCONSUMPTION_HWY         0.778746   0.724594              0.965718
# FUELCONSUMPTION_COMB        0.819482   0.776788              0.995542
# FUELCONSUMPTION_COMB_MPG   -0.808554  -0.770430             -0.935613
# CO2EMISSIONS                0.874154   0.849685              0.898039
# Age                              NaN        NaN                   NaN
# FUELTYPE_E                  0.237674   0.194920              0.567070
# FUELTYPE_X                 -0.266920  -0.339827             -0.319701
# FUELTYPE_Z                  0.165557   0.256011              0.045660
#
#                           FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# ...

# %%
x=data[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB_MPG','FUELCONSUMPTION_COMB','FUELTYPE_X']]
y=data['CO2EMISSIONS']

print(x)

print(y)
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB_MPG  FUELCONSUMPTION_COMB  \
# 0            2.0          4                        33                   8.5
# 1            2.4          4                        29                   9.6
# 2            1.5          4                        48                   5.9
# 3            3.5          6                        25                  11.1
# 4            3.5          6                        27                  10.6
# ...          ...        ...                       ...                   ...
# 1062         3.0          6                        24                  11.8
# 1063         3.2          6                        25                  11.5
# 1064         3.0          6                        24                  11.8
# 1065         3.2          6                        25                  11.3
# 1066         3.2          6                        22                  12.8
#
#       FUELTYPE_X
# 0              0
# 1              0
# ...

# %%
 from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (853, 5)
# (214, 5)
# (853,)
# (214,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
ypred = lr.predict(x_test)
print(ypred)
# Out:
# [260.17518031 201.6001047  201.73431761 170.20145295 310.93345434
#  210.05605787 159.15411258 195.40153265 233.3751676  191.42886809
#  228.80906172 265.32632868 199.99071333 359.26444839 196.64869931
#  178.82882824 187.27943316 315.947237   275.04683791 224.35409395
#  396.89337268 224.7708671  254.18265681 270.24377985 293.42237109
#  238.87440626 138.6971028  284.12561277 173.56643956 236.00304162
#  224.11714177 360.65680958 243.04681379 350.74549776 289.15037707
#  327.33483882 343.14988845 171.18019378 336.13658059 272.82093042
#  238.87440626 370.76634111 226.44578853 269.96437239 254.87883741
#  195.14194501 192.69016917 103.54195081 150.24417705 251.53997617
#  178.02140733 343.48131173 320.7260301  336.95446919 209.8992095
#  282.07580347 210.7097832  286.4967148  264.83304384 169.1114718
#  214.39988752 252.40442611 209.2030289  192.82438208 215.05035786
#  195.40153265 271.07732614 264.81322403 199.94500307 223.03824445
# ...

# %%
diff = pd.DataFrame({"Actual":y_test,"Predicted":ypred})
diff
# Out:
#      Actual   Predicted
# 133     274  260.175180
# 340     200  201.600105
# 948     196  201.734318
# 704     161  170.201453
# 661     320  310.933454
# ..      ...         ...
# 961     301  287.854450
# 523     184  189.416838
# 884     274  266.294088
# 8       267  264.484954
# 415     126  123.633440
#
# [214 rows x 2 columns]

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)

from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y_test,ypred))
print("MSE : ",metrics.mean_squared_error(y_test,ypred))
print("R2 SCORE : ",metrics.r2_score(y_test,ypred))
# Out:
# coefficients :  [ 7.64863446  8.26175212 -3.75878717  3.48090299 11.39543067]
# Intercept :  236.44691065416507
# MAE :  14.977654898680088
# MSE :  446.8106731398054
# R2 SCORE :  0.8898517293142122

# %%
import pandas as pd
data = pd.read_csv("olympic100m.csv")
data
# Out:
#     year   time
# 0   1896  12.00
# 1   1900  11.00
# 2   1904  11.00
# 3   1906  11.20
# 4   1908  10.80
# 5   1912  10.80
# 6   1920  10.80
# 7   1924  10.60
# 8   1928  10.80
# 9   1932  10.30
# 10  1936  10.30
# 11  1948  10.30
# 12  1952  10.40
# 13  1956  10.50
# 14  1960  10.20
# 15  1964  10.00
# 16  1968   9.95
# 17  1972  10.14
# 18  1976  10.06
# 19  1980  10.25
# 20  1984   9.99
# 21  1988   9.92
# 22  1992   9.96
# 23  1996   9.84
# 24  2000   9.87
# 25  2004   9.85
# 26  2008   9.69
# 27  2012   9.63
# 28  2016   9.81

# %%
x=data[['year']]
y=data['time']

print(x)

print(y)
# Out:
#     year
# 0   1896
# 1   1900
# 2   1904
# 3   1906
# 4   1908
# 5   1912
# 6   1920
# 7   1924
# 8   1928
# 9   1932
# 10  1936
# 11  1948
# 12  1952
# 13  1956
# 14  1960
# 15  1964
# 16  1968
# 17  1972
# 18  1976
# 19  1980
# 20  1984
# 21  1988
# 22  1992
# 23  1996
# 24  2000
# 25  2004
# 26  2008
# 27  2012
# 28  2016
# 0     12.00
# 1     11.00
# 2     11.00
# 3     11.20
# 4     10.80
# 5     10.80
# 6     10.80
# 7     10.60
# 8     10.80
# 9     10.30
# 10    10.30
# 11    10.30
# 12    10.40
# 13    10.50
# 14    10.20
# 15    10.00
# 16     9.95
# 17    10.14
# 18    10.06
# 19    10.25
# 20     9.99
# 21     9.92
# 22     9.96
# 23     9.84
# 24     9.87
# 25     9.85
# 26     9.69
# 27     9.63
# 28     9.81
# Name: time, dtype: float64

# %%
# Out:
# (23, 1)
# (6, 1)
# (23,)
# (6,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
y = lr.predict(x)
print(y)
# Out:
# [11.12455601 11.07301534 11.02147467 10.99570434 10.969934   10.91839333
#  10.81531199 10.76377132 10.71223065 10.66068998 10.60914931 10.45452731
#  10.40298664 10.35144597 10.2999053  10.24836463 10.19682396 10.14528329
#  10.09374262 10.04220195  9.99066128  9.93912061  9.88757994  9.83603927
#   9.7844986   9.73295793  9.68141726  9.62987659  9.57833592]

# %%
diff = pd.DataFrame({"Actual":y,"Predicted":y})
diff
# Out:
#        Actual  Predicted
# 0   11.124556  11.124556
# 1   11.073015  11.073015
# 2   11.021475  11.021475
# 3   10.995704  10.995704
# 4   10.969934  10.969934
# 5   10.918393  10.918393
# 6   10.815312  10.815312
# 7   10.763771  10.763771
# 8   10.712231  10.712231
# 9   10.660690  10.660690
# 10  10.609149  10.609149
# 11  10.454527  10.454527
# 12  10.402987  10.402987
# 13  10.351446  10.351446
# 14  10.299905  10.299905
# 15  10.248365  10.248365
# 16  10.196824  10.196824
# 17  10.145283  10.145283
# 18  10.093743  10.093743
# 19  10.042202  10.042202
# 20   9.990661   9.990661
# 21   9.939121   9.939121
# 22   9.887580   9.887580
# 23   9.836039   9.836039
# 24   9.784499   9.784499
# 25   9.732958   9.732958
# 26   9.681417   9.681417
# 27   9.629877   9.629877
# 28   9.578336   9.578336

# %%
print("coefficients : ",lr.coef_)
print("Intercept : ",lr.intercept_)

from sklearn import metrics
print("MAE : ",metrics.mean_absolute_error(y,y))
print("MSE : ",metrics.mean_squared_error(y,y))
print("R2 SCORE : ",metrics.r2_score(y,y))
# Out:
# coefficients :  [-0.01288517]
# Intercept :  35.554833461527906
# MAE :  0.0
# MSE :  0.0
# R2 SCORE :  1.0

# %%
import pandas as pd
data = pd.read_csv("election.csv")
data
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 1        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 2        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 3        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 4        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# ...
