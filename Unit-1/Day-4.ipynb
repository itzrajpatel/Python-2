# %%
import pandas as pd

dataset = pd.read_csv("auto-mpg.csv")
dataset[dataset["horsepower"]=="?"]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin              car name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
dataset = dataset[dataset['horsepower']!='?']
dataset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
dataset[dataset["horsepower"]=="?"]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin, car name]
# Index: []

# %%
dataset.drop('mpg',axis=1) #To delete a particular column
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 0            8         307.0        130    3504          12.0          70
# 1            8         350.0        165    3693          11.5          70
# 2            8         318.0        150    3436          11.0          70
# 3            8         304.0        150    3433          12.0          70
# 4            8         302.0        140    3449          10.5          70
# ..         ...           ...        ...     ...           ...         ...
# 393          4         140.0         86    2790          15.6          82
# 394          4          97.0         52    2130          24.6          82
# 395          4         135.0         84    2295          11.6          82
# 396          4         120.0         79    2625          18.6          82
# 397          4         119.0         82    2720          19.4          82
#
#      origin                   car name
# 0         1  chevrolet chevelle malibu
# ...

# %%
"""---Finding & Removing Outliers---"""

#IQR(Interquartile Range)
# IQR = Q3 - Q1
# (i) low = Q1 - 1.5*IQR
# (ii) high = Q1 + 1.5*IQR

# %%
import pandas as pd

dataset = pd.read_csv('auto-mpg.csv')
dataset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
def find_outliers(ds,col):
    quart1 = ds[col].quantile(0.25)
    quart3 = ds[col].quantile(0.75)
    IQR = quart3 - quart1
    low_val = quart1 - 1.5*IQR
    high_val = quart3 + 1.5*IQR
    print(low_val)
    print(high_val)
    ds = ds.loc[(ds[col]<low_val) | (ds[col]>high_val)]
    return ds

# %%
find_outliers(dataset,'acceleration')
# Out:
# 8.800000000000008
# 22.199999999999992
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 7    14.0          8         440.0        215    4312           8.5
# 9    15.0          8         390.0        190    3850           8.5
# 11   14.0          8         340.0        160    3609           8.0
# 59   23.0          4          97.0         54    2254          23.5
# 195  29.0          4          85.0         52    2035          22.2
# 299  27.2          4         141.0         71    3190          24.8
# 300  23.9          8         260.0         90    3420          22.2
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                           car name
# 7            70       1                  plymouth fury iii
# 9            70       1                 amc ambassador dpl
# 11           70       1                 plymouth 'cuda 340
# ...

# %%
find_outliers(dataset,'mpg')
# Out:
# 0.25
# 46.25
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin   car name
# 322          80       3  mazda glc

# %%
def remove_outliers(ds,col):
    quart1 = ds[col].quantile(0.25)
    quart3 = ds[col].quantile(0.75)
    IQR = quart3 - quart1
    low_val = quart1 - 1.5*IQR
    high_val = quart3 + 1.5*IQR
    print(low_val)
    print(high_val)
    ds = ds.loc[(ds[col]>=low_val) & (ds[col]<=high_val)]
    return ds

# %%
remove_outliers(dataset,'acceleration')
# Out:
# 8.800000000000008
# 22.199999999999992
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
remove_outliers(dataset,'mpg')
# Out:
# 0.25
# 46.25
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
new_data = remove_outliers(dataset,'acceleration')
new_data.info()
# Out:
# 8.800000000000008
# 22.199999999999992
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           389 non-null    float64
#  1   cylinders     389 non-null    int64
#  2   displacement  389 non-null    float64
#  3   horsepower    389 non-null    object
#  4   weight        389 non-null    int64
#  5   acceleration  389 non-null    float64
#  6   model year    389 non-null    int64
#  7   origin        389 non-null    int64
#  8   car name      389 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 30.4+ KB

# %%
"""---Drop & Remove Duplicates---"""

import pandas as pd

data = {"A":["Team A","Team B","Team B","Team C","Team A","Team B"],
        "B":[50,40,40,30,50,10],
        "C":[True,False,False,False,True,False]}
df = pd.DataFrame(data)
df
# Out:
#         A   B      C
# 0  Team A  50   True
# 1  Team B  40  False
# 2  Team B  40  False
# 3  Team C  30  False
# 4  Team A  50   True
# 5  Team B  10  False

# %%
dups = df.duplicated()
print(dups)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#         A   B      C
# 0  Team A  50   True
# 1  Team B  40  False
# 3  Team C  30  False
# 5  Team B  10  False

# %%
#To make index in sequence
df = df.reset_index(drop=True)
df
# Out:
#         A   B      C
# 0  Team A  50   True
# 1  Team B  40  False
# 2  Team C  30  False
# 3  Team B  10  False

# %%
# Example-1

import pandas as pd

data = pd.read_csv('ipl-matches.csv')
data
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#How many matches have gone in super over

data[data['SuperOver']=="Y"].shape[0]
# Out:
# 14

# %%
#How many matches won by toss winner of the match

data[data['TossWinner']==data['WinningTeam']].shape[0]
# Out:
# 489

# %%
#How many matches GT won the toss & elected to bat

data[(data['TossWinner']=="Gujarat Titans") & (data['TossDecision']=="bat")].shape[0]
# Out:
# 4

# %%
#Player of the match

data[data['Player_of_Match']=="HH Pandya"].shape[0]
# Out:
# 8

# %%
#HH Pandya player of the match in RR

data[(data['Player_of_Match']=="HH Pandya") & ((data['Team1']=='Rajasthan Royals') | (data['Team2']=="Rajasthan Royals"))].shape[0]
# Out:
# 2

# %%
#How many matches GT played

data[(data['Team1']=="Gujarat Titans") | (data['Team2']=="Gujarat Titans")].shape[0]
# Out:
# 16

# %%
#How many matches GT won

data[data['WinningTeam']=="Gujarat Titans"].shape[0]
# Out:
# 12
