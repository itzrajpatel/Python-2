# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
print(movies[[0,1,3,4,10,15]])
# Out:
# movie
# Uri: The Surgical Strike       Vicky Kaushal
# Battalion 609                    Vicky Ahuja
# Why Cheat India                Emraan Hashmi
# Evening Shadows             Mona Ambegaonkar
# Amavas                             Ali Asgar
# Badla (2019 film)           Amitabh Bachchan
# Name: lead, dtype: object

# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
print("Alia Bhatt" in movies.values)
# Out:
# True

# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
print("Uri: The Surgical Strike" in movies)
# Out:
# True

# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
num_movies = movies.value_counts()
print(num_movies)
# Out:
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Nargis Fakhri         1
# Gulshan Grover        1
# Puneet Singh Ratn     1
# Hema Malini           1
# Ankit                 1
# Name: lead, Length: 566, dtype: int64

# %%
import pandas as pd

movies=pd.read_csv("bollywood.csv", index_col='movie', squeeze=True)
print(num_movies[num_movies > 20])
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %%
import pandas as pd

sub=pd.read_csv("subs.csv", squeeze=True)
print(sub[sub>200].size)
# Out:
# 59

# %%
# 1

import pandas as pd

marks={'Zulfi':55, 'Kishor':60, 'Raj':80}
myvar=pd.Series(marks, name='Result')
print(myvar)
# Out:
# Zulfi     55
# Kishor    60
# Raj       80
# Name: Result, dtype: int64

# %%
# 2

import pandas as pd

marks={'Zulfi':55, 'Kishor':60, 'Raj':80}
myvar=pd.Series(marks, name='Result')
myvar[1]=100
print(myvar)
# Out:
# Zulfi      55
# Kishor    100
# Raj        80
# Name: Result, dtype: int64

# %%
# 3

import pandas as pd

marks={'Zulfi':55, 'Kishor':60, 'Raj':80}
myvar=pd.Series(marks, name='Result')
myvar=100+myvar
print(myvar)
# Out:
# Zulfi     155
# Kishor    160
# Raj       180
# Name: Result, dtype: int64

# %%
# 4

import pandas as pd

marks={'Zulfi':55, 'Kishor':60, 'Raj':80}
myvar=pd.Series(marks, name='Result')
myvar=100+myvar
print(myvar>=100)
# Out:
# Zulfi     True
# Kishor    True
# Raj       True
# Name: Result, dtype: bool

# %%
import pandas as pd

a=pd.Series([2,4,6,8,10])
b=pd.Series([1,3,5,7,10])
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    20
# dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64
# 0      2
# 1     12
# 2     30
# 3     56
# 4    100
# dtype: int64
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.000000
# dtype: float64

# %%
import pandas as pd

a=pd.Series([2,4,6,8,10])
b=pd.Series([1,3,5,7,10])
print(a==b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
print(kohli)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
kohli = kohli.sort_values(ascending=True) # For highest score
print(kohli)
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
print(kohli.head(10))
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
kohli = kohli.sort_values(ascending=False) # For top 10 highest score
print(kohli.head(10))
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
# 82      99
# 81      93
# 145     92
# 178     90
# 160     84
# Name: runs, dtype: int64

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
print(kohli[kohli.values==0].size)
# Out:
# 9

# %%
import pandas as pd

kohli=pd.read_csv("kohli_ipl.csv", index_col="match_no", squeeze=True)
print(kohli[(kohli.values>90) & (kohli.values<100)])
# Out:
# match_no
# 81     93
# 82     99
# 145    92
# Name: runs, dtype: int64

# %%
"""---DataFrame---"""

import pandas as pd

data={"calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  Duration
# 0       400        50
# 1       360        45
# 2       390        40

# %%
import pandas as pd

data={"Calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data)
print(df.loc[0]) # or you can use "df.iloc[0]". But it is only used when index is in numeric form.
print(df.loc[1])
print(df.loc[2])
# Out:
# Calories    400
# Duration     50
# Name: 0, dtype: int64
# Calories    360
# Duration     45
# Name: 1, dtype: int64
# Calories    390
# Duration     40
# Name: 2, dtype: int64

# %%
import pandas as pd

data={"Calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data)
print(df['Calories'])
print(df['Duration'])
# Out:
# 0    400
# 1    360
# 2    390
# Name: Calories, dtype: int64
# 0    50
# 1    45
# 2    40
# Name: Duration, dtype: int64

# %%
import pandas as pd

data={"Calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data)
print(df.loc[[0,1]])
# Out:
#    Calories  Duration
# 0       400        50
# 1       360        45

# %%
import pandas as pd

data={"Calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data)
print(df['Calories'][0])
print(df['Duration'][0])
# Out:
# 400
# 50

# %%
"""---DataFrame---"""

import pandas as pd

data={"calories":[400,360,390], "Duration":[50,45,40]}
df = pd.DataFrame(data, index=['Day1','Day2','Day3'])
print(df.loc['Day1'])
# Out:
# calories    400
# Duration     50
# Name: Day1, dtype: int64

# %%
df[::2]
# Out:
#       calories  Duration
# Day1       400        50
# Day3       390        40

# %%
import pandas as pd

data=pd.read_csv("auto-mpg.csv")
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
import pandas as pd

data=pd.read_csv("auto-mpg.csv")
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# ...

# %%
data.loc[32]
# Out:
# mpg                     25
# cylinders                4
# displacement            98
# horsepower               ?
# weight                2046
# acceleration            19
# model year              71
# origin                   1
# car name        ford pinto
# Name: 32, dtype: object

# %%
data.loc[5:15] # with "loc"
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# 13  14.0          8         455.0        225    3086          10.0
# 14  24.0          4         113.0         95    2372          15.0
# 15  22.0          6         198.0         95    2833          15.5
#
#     model year  origin                 car name
# 5           70       1         ford galaxie 500
# 6           70       1         chevrolet impala
# ...

# %%
data[5:15] # without "loc"
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# 13  14.0          8         455.0        225    3086          10.0
# 14  24.0          4         113.0         95    2372          15.0
#
#     model year  origin                 car name
# 5           70       1         ford galaxie 500
# 6           70       1         chevrolet impala
# 7           70       1        plymouth fury iii
# ...

# %%
data['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
data['mpg'][4]
# Out:
# 17.0

# %%
data[['mpg','cylinders','model year']]
# Out:
#       mpg  cylinders  model year
# 0    18.0          8          70
# 1    15.0          8          70
# 2    18.0          8          70
# 3    16.0          8          70
# 4    17.0          8          70
# ..    ...        ...         ...
# 393  27.0          4          82
# 394  44.0          4          82
# 395  32.0          4          82
# 396  28.0          4          82
# 397  31.0          4          82
#
# [398 rows x 3 columns]

# %%
data[['mpg','cylinders','model year']].loc[[1,3,4,5]]
# Out:
#     mpg  cylinders  model year
# 1  15.0          8          70
# 3  16.0          8          70
# 4  17.0          8          70
# 5  15.0          8          70

# %%
data.shape # Output: (rows,cols)
# Out:
# (398, 9)

# %%
data.shape[0] # Output: (rows)
# Out:
# 398

# %%
data.shape[1] # Output: (cols)
# Out:
# 9

# %%
data.describe() # This will not show all columns that have datatype "object"
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.describe(percentiles=[.30,.45,.55]) # to change percentile
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 30%     18.000000    4.000000    112.000000  2301.000000     14.200000
# 45%     21.065000    4.000000    140.000000  2670.650000     15.000000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 55%     24.000000    6.000000    168.000000  2937.200000     15.735000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 30%     73.000000    1.000000
# 45%     75.000000    1.000000
# 50%     76.000000    1.000000
# ...

# %%
data.describe(include='all') # This will show all columns
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
import numpy as np

data.describe(include=[np.number]) # It will include numerical data
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
import numpy as np

data.describe(exclude=[np.number]) # It will exclude numerical data
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6
