# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
x = range(1,11)
plt.plot(x,values)
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values)
plt.plot(x,values1)
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values,'r')
plt.plot(x,values1,'m')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values,'--')
plt.plot(x,values1,':')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values,'o--')
plt.plot(x,values1,'v:')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values,'o--')
plt.plot(x,values1,'v:')
plt.savefig('myplot.png',format='png')
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
values1 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,values,'o--')
plt.plot(x,values1,'v:')
plt.xlabel("Range")
plt.ylabel("Values")
plt.title("Graph-1")
plt.show()

# %%
import matplotlib.pyplot as plt

values = [1,5,8,9,2,0,3,10,4,7]
x = range(1,11)
plt.annotate(text='First Value',xy=[1,1])
plt.annotate(text='Last Value',xy=[10,7])
plt.annotate(text='Middle Value',xy=[6,0])
plt.plot(x,values)
plt.show()

# %%
"""===============   =============
   Location String   Location Code
   ===============   =============
    'best'            0 (default)
    'upper right'     1
    'upper left'      2
    'lower left'      3
    'lower right'     4
    'right'           5
    'center left'     6
    'center right'    7
    'lower center'    8
    'upper center'    9
    'center'          10
    ===============   ============="""

import matplotlib.pyplot as plt

y1 = [1,5,8,9,2,0,3,10,4,7]
y2 = [3,8,9,2,1,2,4,7,6,6]
x = range(1,11)
plt.plot(x,y1,label='Graph-1')
plt.plot(x,y2,label='Graph-2')
plt.legend(loc=0)
plt.show()

# %%
"""---Area Plot---"""

import matplotlib.pyplot as plt

x = range(1,6)
y = [1,4,6,8,4]
plt.fill_between(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = range(1,6)
y = [1,4,6,8,4]
plt.fill_between(x,y,color='skyblue',alpha=0.4) #alpha = opacity (0 - 1)
plt.show()

# %%
import matplotlib.pyplot as plt

x = range(1,6)
y = [1,4,6,8,4]
plt.fill_between(x,y,alpha=0.4)
plt.plot(x,y,color='red',alpha=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

time = np.arange(12)
income = np.array([5,9,6,6,10,7,6,4,4,5,6,4])
expense = np.array([6,6,8,3,6,9,7,8,6,6,4,8])

# %%
plt.plot(time,income,color='green')
plt.plot(time,expense,color='red')
plt.fill_between(time,income,expense,where=(income>expense),color='green',alpha=0.25,label='Positive',interpolate=True)
plt.fill_between(time,income,expense,where=(income<=expense),color='red',alpha=0.25,label='Negative',interpolate=True)
plt.xlabel('Time')
plt.xticks(range(0,11)) # to show all nos.
plt.ylabel('Values')
plt.yticks(range(0,11)) # to show all nos.
plt.title('Income & Expense Graph')
plt.legend()
plt.show()

# %%
"""---Stacked Area Chart---"""

import matplotlib.pyplot as plt

x = range(1,6)
y1 = [1,4,6,8,9]
y2 = [2,2,7,10,12]
y3 = [2,8,5,10,6]
plt.stackplot(x,y1,y2,y3,labels=['A','B','C'],colors=['red','blue','green'])
plt.legend(loc='upper left')
plt.show()

# %%
"""---Stacked Area Chart---"""

import matplotlib.pyplot as plt

x = range(1,6)
y1 = [10,10,10,10,10]
y2 = [10,10,10,10,10]
y3 = [10,10,10,10,10]
plt.stackplot(x,y1,y2,y3,labels=['A','B','C'],colors=['yellow','red','black'])
plt.title("Germany")
plt.axis("off")
plt.show()

# %%
"""---Box Plot(used to represent outliers)---"""

import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('auto-mpg.csv')
plt.boxplot(data['mpg'],widths=0.75,notch=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('auto-mpg.csv')
plt.boxplot(data['acceleration'],widths=0.75,notch=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('auto-mpg.csv')
plt.boxplot(data['model year'],widths=0.75,notch=True)
plt.show()

# %%
"""---Scatter Plot---"""

import matplotlib.pyplot as plt
import numpy as np

x1 = 5*np.random.rand(40)
x2 = 5*np.random.rand(40)+25
x3 = 25*np.random.rand(20)
x = np.concatenate((x1,x2,x3))
y1 = 5*np.random.rand(40)
y2 = 5*np.random.rand(40)+25
y3 = 25*np.random.rand(20)
y = np.concatenate((y1,y2,y3))
color_array=['b']*40 + ['g']*40 + ['r']*20
plt.scatter(x,y,s=[100],marker='^',c=color_array)
plt.show()

# %%
"""---Waffle Charts---"""
# If lib is not instaled then, "pip install pywaffle"

import numpy as np
import matplotlib.pyplot as plt
from pywaffle import Waffle

data = {'Phone':['Apple','Samsung','RealMe','Xiomi','Google Pixel'],
        'Stock':[45,12,8,5,50]}
df = pd.DataFrame(data)
fig = plt.figure(FigureClass=Waffle, rows=10, values=df.Stock, labels=list(df.Phone)) # OR values=df['Stock'] & labels=list(df['Phone'])
# Out:
# <Waffle size 432x288 with 1 Axes>
